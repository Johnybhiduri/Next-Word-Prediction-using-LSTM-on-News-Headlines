# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import string
import re

# %%
data = pd.read_csv('/kaggle/input/us-crime-data/US_Crime_Data.csv')
data.sample(10)
# Out:
#                Date                                              Title  \
# 1237  4/27/17 10:03  Within Trump's first 100 days, anti-Muslim inc...
# 6481   12/4/17 7:45  Gates Police: Man pointed gun, yelled racial s...
# 6106  11/13/17 8:30  FBI reports: Hate crimes rose for 2nd year in ...
# 4528    9/4/17 4:20  Nuke F******G Sikhs': Man Vandalizes Sikh Temp...
# 3314   7/13/17 1:03  Man arrested in DC hit-and-run that critically...
# 1588  5/19/17 14:56  Benefit concert Saturday in Troy for victims o...
# 4923  9/26/17 15:41  Victims in Thousands of Potential Hate Crimes ...
# 6658  12/11/17 8:48  Facebook Live Torture Case: Teen Takes Plea De...
# 306    3/5/17 10:00  Police Contact FBI After Sikh Shot Outside Sea...
# 444    3/10/17 2:30  Sikh man shooting in US: Kent police terms inc...
#
#             Organization        City State  \
# 1237                 Mic    New York    NY
# 6481  rochesterfirst.com      Mendon    NY
# 6106              FOX 61    Hartford    CT
# 4528       Carbonated.tv   San Ramon    CA
# 3314                WTOP  Washington    DC
# 1588  Albany Times Union      Albany    NY
# 4923   Tri County Sentry         NaN   NaN
# 6658           Patch.com    New York   NaN
# 306             OPB News    Portland    OR
# 444       Tech Know Bits     Cumming    GA
#
#                                                     URL  \
# 1237  http://mic.com/articles/175332/within-trump-s-...
# 6481  http://www.rochesterfirst.com/news/local-news/...
# 6106  http://fox61.com/2017/11/13/fbi-reports-hate-c...
# 4528  http://www.carbonated.tv/news/sikh-temple-vand...
# 3314  http://wtop.com/dc/2017/07/hit-run-transgender...
# 1588  http://www.timesunion.com/allwcm/article/Benef...
# 4923  http://tricountysentry.com/blog/victims-in-tho...
# 6658  https://patch.com/illinois/crystallake/faceboo...
# 306   http://www.opb.org/news/article/police-fbi-sik...
# 444   http://techknowbits.com/2017/03/sikh-man-shoot...
#
#                                                 Keyword  \
# 1237  american anti border cair cbp customs donald i...
# 6481                                                NaN
# 6106  4229 andrew baltimore burton crimes fbi freddi...
# 4528  coalition facebook feliz hate hollywood los_an...
# 3314  anderson captain corado critically davon faceb...
# 1588  arson cold concert crime felonies garage hate ...
# 4923  attorney bureau crime crimes fbi general hate ...
# 6658  brittany chicago covington crime crystal donal...
# 306                                                 NaN
# 444                                                 NaN
#
#                                                 Summary
# 1237  by Sarah A. Harvard\tPresident Donald Trump ha...
# 6481                                                NaN
# 6106  Posted 7:06 PM, November 13, 2017, by AP\tBALT...
# 4528  The police allegedly did not seem too interest...
# 3314  By Jack Pointer July 13, 2017 4:05 am\tWASHING...
# 1588  TROY — A benefit concert to help the family wh...
# 4923  By Joe Sexton\tMore than half of the people wh...
# 6658  She and three others were accused of kidnappin...
# 306                                                 NaN
# 444                                                 NaN

# %%
data.isna().sum()
# Out:
# Date               0
# Title              1
# Organization       0
# City            1167
# State           1245
# URL                0
# Keyword         1176
# Summary         2256
# dtype: int64

# %% [markdown]
# ## For this model we just need headlines

# %%
df = data[['Title']]
df = df.dropna().reset_index(drop = True)
df.head()
# Out:
#                                                Title
# 0  Pizza Hut driver who killed co-worker with sho...
# 1  Residents of NJ township receiving KKK promoti...
# 2  House OKs bill to expand Kentucky's hate crime...
# 3  Amid Protests, 'Blue Lives Matter' Bill Passes...
# 4  Lafourche inmates charged with hate crimes in ...

# %%
df['Title'][123]
# Out:
# 'St. Louis suburb victimized by cemetery vandalism mulling hate crimes registry'

# %%
df.shape
# Out:
# (6782, 1)

# %% [markdown]
# # Removing Punctuations

# %%
def clean_text(df):
    df['Title'] = df['Title'].apply(lambda x : x.lower())
    tokens = df['Title'].str.replace('[{}]'.format(string.punctuation), '')
    return tokens

# %%
tokens = clean_text(df)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
tokens
# Out:
# 0       pizza hut driver who killed coworker with shot...
# 1       residents of nj township receiving kkk promoti...
# 2       house oks bill to expand kentuckys hate crimes...
# 3       amid protests blue lives matter bill passes ke...
# 4       lafourche inmates charged with hate crimes in ...
#                               ...
# 6777    police rash of vandalism on margate menorahs i...
# 6778    exstudent accused of smearing used tampon on r...
# 6779    queensbury woman charged with hate crime again...
# 6780    hate crime hartford student accused of smearin...
# 6781    police make arrest following alleged hate crim...
# Name: Title, Length: 6782, dtype: object

# %%
len(set(tokens))
# Out:
# 6563

# %% [markdown]
# # Tokenizing

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(tokens)
seq = tokenizer.texts_to_sequences(tokens)

# %%
seq[:10]
# Out:
# [[3973, 3974, 450, 47, 88, 3975, 12, 2211, 103, 1370, 2803],
#  [830, 4, 423, 1558, 2212, 470, 3976, 672],
#  [257, 1846, 75, 5, 593, 3977, 1, 6, 36],
#  [721, 898, 480, 274, 301, 75, 481, 634, 257],
#  [3978, 2804, 16, 12, 1, 6, 3, 424, 19],
#  [13, 722, 1, 2, 48, 594, 3979, 5, 401],
#  [3980, 480, 274, 301, 75, 21, 1371, 2805, 5, 214, 3981, 173],
#  [194, 320, 18, 402, 2806, 239, 15, 98, 38],
#  [194,
#   320,
#   18,
#   402,
#   2806,
#   239,
#   15,
#   98,
#   38,
#   635,
#   174,
#   556,
#   557,
#   14,
#   498,
#   558,
#   275,
#   42],
#  [33, 174, 673, 302, 2, 1372, 2807, 3, 2213]]

# %% [markdown]
# # Creating input and output data list

# %%
x = []
y = []
total_words_drop = 0
for i in seq:
    if len(i) > 1:
        for j in range(1, len(i)):
            x.append(i[:j])
            y.append(i[j])
            
    else : 
        total_words_drop +=1
print('Total Words Dropped : {}'.format(total_words_drop))
# Out:
# Total Words Dropped : 12

# %%
y[: 10]
# Out:
# [3974, 450, 47, 88, 3975, 12, 2211, 103, 1370, 2803]

# %% [markdown]
# # Padding sequences

# %%
x = tf.keras.preprocessing.sequence.pad_sequences(x)

# %%
x.shape
# Out:
# (64701, 49)

# %% [markdown]
# # Shaping y same as x

# %%
y = tf.keras.utils.to_categorical(y)

# %%
y.shape
# Out:
# (64701, 7569)

# %% [markdown]
# # Vocab Size : total no. of unique words

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 7569

# %% [markdown]
# # LSTM Model

# %%
model = tf.keras.Sequential([tf.keras.layers.Embedding(vocab_size,49 ),
                            tf.keras.layers.LSTM(100, return_sequences = True),
                            tf.keras.layers.LSTM(100),
                            tf.keras.layers.Dense(100, activation = 'relu'),
                            tf.keras.layers.Dense(vocab_size, activation = 'softmax')])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 49)          370881
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 100)         60000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 7569)              764469
# =================================================================
# Total params: 1,285,850
# Trainable params: 1,285,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss  = 'categorical_crossentropy',
             optimizer = 'adam',
             metrics = ['accuracy'],
             )

# %%
history = model.fit(x,y,
                   epochs = 100,
                    batch_size = 256,
                    callbacks = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                                               patience = 5,
                                                               restore_best_weights = True))
# Out:
# 2023-01-25 12:22:51.670457: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1958887476 exceeds 10% of free system memory.
# 2023-01-25 12:22:53.639515: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1958887476 exceeds 10% of free system memory.
# Epoch 1/100
# 253/253 [==============================] - 5s 19ms/step - loss: 5.9973 - accuracy: 0.1323
# Epoch 2/100
# 253/253 [==============================] - 4s 18ms/step - loss: 5.9171 - accuracy: 0.1353
# Epoch 3/100
# 253/253 [==============================] - 5s 18ms/step - loss: 5.8196 - accuracy: 0.1390
# Epoch 4/100
# 253/253 [==============================] - 4s 18ms/step - loss: 5.7040 - accuracy: 0.1451
# Epoch 5/100
# 253/253 [==============================] - 5s 18ms/step - loss: 5.6015 - accuracy: 0.1516
# Epoch 6/100
# 253/253 [==============================] - 4s 18ms/step - loss: 5.5048 - accuracy: 0.1591
# Epoch 7/100
# 253/253 [==============================] - 4s 18ms/step - loss: 5.4107 - accuracy: 0.1670
# Epoch 8/100
# 253/253 [==============================] - 5s 19ms/step - loss: 5.3241 - accuracy: 0.1730
# Epoch 9/100
# 253/253 [==============================] - 5s 18ms/step - loss: 5.2395 - accuracy: 0.1793
# Epoch 10/100
# 253/253 [==============================] - 5s 18ms/step - loss: 5.1583 - accuracy: 0.1863
# Epoch 11/100
# 253/253 [==============================] - 4s 18ms/step - loss: 5.0726 - accuracy: 0.1934
# Epoch 12/100
# 253/253 [==============================] - 4s 18ms/step - loss: 4.9860 - accuracy: 0.1993
# Epoch 13/100
# 253/253 [==============================] - 5s 18ms/step - loss: 4.8971 - accuracy: 0.2072
# Epoch 14/100
# 253/253 [==============================] - 4s 17ms/step - loss: 4.8109 - accuracy: 0.2128
# Epoch 15/100
# 253/253 [==============================] - 5s 19ms/step - loss: 4.7216 - accuracy: 0.2187
# Epoch 16/100
# 253/253 [==============================] - 4s 18ms/step - loss: 4.6366 - accuracy: 0.2250
# Epoch 17/100
# 253/253 [==============================] - 4s 17ms/step - loss: 4.5506 - accuracy: 0.2300
# Epoch 18/100
# 253/253 [==============================] - 4s 18ms/step - loss: 4.4649 - accuracy: 0.2373
# Epoch 19/100
# 253/253 [==============================] - 4s 17ms/step - loss: 4.3820 - accuracy: 0.2431
# Epoch 20/100
# 253/253 [==============================] - 4s 18ms/step - loss: 4.2992 - accuracy: 0.2488
# Epoch 21/100
# 253/253 [==============================] - 4s 17ms/step - loss: 4.2179 - accuracy: 0.2542
# Epoch 22/100
# 253/253 [==============================] - 5s 19ms/step - loss: 4.1392 - accuracy: 0.2597
# Epoch 23/100
# 253/253 [==============================] - 4s 18ms/step - loss: 4.0641 - accuracy: 0.2653
# Epoch 24/100
# 253/253 [==============================] - 4s 18ms/step - loss: 3.9953 - accuracy: 0.2706
# Epoch 25/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.9234 - accuracy: 0.2761
# Epoch 26/100
# 253/253 [==============================] - 4s 18ms/step - loss: 3.8532 - accuracy: 0.2820
# Epoch 27/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.7892 - accuracy: 0.2872
# Epoch 28/100
# 253/253 [==============================] - 4s 18ms/step - loss: 3.7272 - accuracy: 0.2937
# Epoch 29/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.6653 - accuracy: 0.2992
# Epoch 30/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.6035 - accuracy: 0.3059
# Epoch 31/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.5500 - accuracy: 0.3121
# Epoch 32/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.4960 - accuracy: 0.3187
# Epoch 33/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.4457 - accuracy: 0.3261
# Epoch 34/100
# 253/253 [==============================] - 5s 19ms/step - loss: 3.3941 - accuracy: 0.3323
# Epoch 35/100
# 253/253 [==============================] - 4s 18ms/step - loss: 3.3431 - accuracy: 0.3405
# Epoch 36/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.2951 - accuracy: 0.3442
# Epoch 37/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.2529 - accuracy: 0.3510
# Epoch 38/100
# 253/253 [==============================] - 4s 18ms/step - loss: 3.2075 - accuracy: 0.3568
# Epoch 39/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.1623 - accuracy: 0.3650
# Epoch 40/100
# 253/253 [==============================] - 4s 18ms/step - loss: 3.1208 - accuracy: 0.3706
# Epoch 41/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.0804 - accuracy: 0.3764
# Epoch 42/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.0448 - accuracy: 0.3805
# Epoch 43/100
# 253/253 [==============================] - 5s 18ms/step - loss: 3.0041 - accuracy: 0.3848
# Epoch 44/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.9714 - accuracy: 0.3914
# Epoch 45/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.9299 - accuracy: 0.3969
# Epoch 46/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.8950 - accuracy: 0.4010
# Epoch 47/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.8607 - accuracy: 0.4065
# Epoch 48/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.8276 - accuracy: 0.4108
# Epoch 49/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.7965 - accuracy: 0.4171
# Epoch 50/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.7639 - accuracy: 0.4214
# Epoch 51/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.7303 - accuracy: 0.4257
# Epoch 52/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.7080 - accuracy: 0.4288
# Epoch 53/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.6728 - accuracy: 0.4351
# Epoch 54/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.6441 - accuracy: 0.4400
# Epoch 55/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.6183 - accuracy: 0.4417
# Epoch 56/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.5898 - accuracy: 0.4468
# Epoch 57/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.5608 - accuracy: 0.4518
# Epoch 58/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.5357 - accuracy: 0.4566
# Epoch 59/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.5138 - accuracy: 0.4586
# Epoch 60/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.4875 - accuracy: 0.4639
# Epoch 61/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.4635 - accuracy: 0.4676
# Epoch 62/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.4423 - accuracy: 0.4704
# Epoch 63/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.4168 - accuracy: 0.4755
# Epoch 64/100
# 253/253 [==============================] - 5s 19ms/step - loss: 2.3947 - accuracy: 0.4792
# Epoch 65/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.3751 - accuracy: 0.4826
# Epoch 66/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.3515 - accuracy: 0.4869
# Epoch 67/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.3281 - accuracy: 0.4893
# Epoch 68/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.3109 - accuracy: 0.4946
# Epoch 69/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.2857 - accuracy: 0.4978
# Epoch 70/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.2657 - accuracy: 0.5009
# Epoch 71/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.2488 - accuracy: 0.5028
# Epoch 72/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.2298 - accuracy: 0.5075
# Epoch 73/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.2138 - accuracy: 0.5092
# Epoch 74/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.1911 - accuracy: 0.5139
# Epoch 75/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.1762 - accuracy: 0.5159
# Epoch 76/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.1557 - accuracy: 0.5200
# Epoch 77/100
# 253/253 [==============================] - 5s 19ms/step - loss: 2.1408 - accuracy: 0.5224
# Epoch 78/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.1220 - accuracy: 0.5253
# Epoch 79/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.1031 - accuracy: 0.5305
# Epoch 80/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.0947 - accuracy: 0.5310
# Epoch 81/100
# 253/253 [==============================] - 4s 18ms/step - loss: 2.0701 - accuracy: 0.5345
# Epoch 82/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.0569 - accuracy: 0.5384
# Epoch 83/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.0405 - accuracy: 0.5399
# Epoch 84/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.0238 - accuracy: 0.5445
# Epoch 85/100
# 253/253 [==============================] - 5s 18ms/step - loss: 2.0074 - accuracy: 0.5471
# Epoch 86/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.9936 - accuracy: 0.5483
# Epoch 87/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.9795 - accuracy: 0.5517
# Epoch 88/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.9623 - accuracy: 0.5549
# Epoch 89/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.9499 - accuracy: 0.5579
# Epoch 90/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.9381 - accuracy: 0.5585
# Epoch 91/100
# 253/253 [==============================] - 5s 19ms/step - loss: 1.9232 - accuracy: 0.5617
# Epoch 92/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.9018 - accuracy: 0.5660
# Epoch 93/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.8942 - accuracy: 0.5679
# Epoch 94/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.8784 - accuracy: 0.5717
# Epoch 95/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.8647 - accuracy: 0.5727
# Epoch 96/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.8514 - accuracy: 0.5766
# Epoch 97/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.8427 - accuracy: 0.5776
# Epoch 98/100
# 253/253 [==============================] - 5s 19ms/step - loss: 1.8254 - accuracy: 0.5819
# Epoch 99/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.8166 - accuracy: 0.5829
# Epoch 100/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.8061 - accuracy: 0.5846

# %% [markdown]
# # Saving model

# %%
model.save('model.h5')

# %% [markdown]
# # Vocab Array : list of all the unique words

# %%
vocab_array = np.array(list(tokenizer.word_index.keys()))
vocab_array
# Out:
# array(['hate', 'crime', 'in', ..., 'walks', 'lgbti', 'retires'],
#       dtype='<U23')

# %% [markdown]
# # Final Function for Predictions

# %%
def make_predictions(text, n_words):
    for i in range(n_words):
        text_tokenize = tokenizer.texts_to_sequences([text])
        text_padding  = tf.keras.preprocessing.sequence.pad_sequences(text_tokenize, maxlen = 49)
        prediction = np.squeeze(np.argmax(model.predict(text_padding), axis = -1))
        prediction = str(vocab_array[prediction - 1])
        text += " " + prediction
    return text

# %% [markdown]
# # Testing Model

# %%
make_predictions('california',5)
# Out:
# 'california man accused of hate crime'

# %%
make_predictions('new york',8)
# Out:
# 'new york mosque found not guilty to death on muslim'

# %%
make_predictions('highway',8)
# Out:
# 'highway toppled against white nationalism life to tackle online'

# %% [markdown]
# > Its so fun to get prediction !
#
# # Thanks!
